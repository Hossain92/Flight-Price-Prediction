# %%
#importing basic labries

import os
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir(r'E:\python practice')

train_df = pd.read_excel('Data_Train.xlsx')
train_df.sample(5)
# Out:
#            Airline Date_of_Journey   Source Destination            Route  \
# 7267   Jet Airways       3/06/2019    Delhi      Cochin  DEL → BOM → COK
# 7002   Jet Airways       3/06/2019    Delhi      Cochin  DEL → BOM → COK
# 8077   Jet Airways       3/06/2019    Delhi      Cochin  DEL → BOM → COK
# 10628     SpiceJet       9/05/2019  Kolkata    Banglore  CCU → IXB → BLR
# 1671        IndiGo      12/06/2019  Chennai     Kolkata        MAA → CCU
#
#       Dep_Time  Arrival_Time Duration Total_Stops  \
# 7267     10:00  04:25 04 Jun  18h 25m      1 stop
# 7002     11:30         19:00   7h 30m      1 stop
# 8077     14:00  04:25 04 Jun  14h 25m      1 stop
# 10628    15:55         21:25   5h 30m      1 stop
# 1671     13:15         15:35   2h 20m    non-stop
#
#                    Additional_Info  Price
# 7267   In-flight meal not included  11627
# 7002   In-flight meal not included  10262
# 8077                       No info  14714
# 10628                      No info   8224
# ...

# %%
train_df.shape
# Out:
# (10683, 11)

# %%
train_df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# Loading Test dataset

# %%
test_df = pd.read_excel('Test_set.xlsx')
test_df.sample(5)
# Out:
#           Airline Date_of_Journey    Source Destination            Route  \
# 1629  Jet Airways       1/04/2019   Kolkata    Banglore  CCU → DEL → BLR
# 511      SpiceJet       9/03/2019     Delhi      Cochin  DEL → MAA → COK
# 1754     Air Asia      18/06/2019  Banglore       Delhi        BLR → DEL
# 1041  Jet Airways      12/06/2019     Delhi      Cochin  DEL → BOM → COK
# 807      SpiceJet      12/06/2019   Chennai     Kolkata        MAA → CCU
#
#      Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 1629    20:25  23:35 02 Apr  27h 10m      1 stop                      No info
# 511     15:55         21:55       6h      1 stop                      No info
# 1754    04:55         07:45   2h 50m    non-stop                      No info
# 1041    10:00         19:00       9h      1 stop  In-flight meal not included
# 807     17:45         20:05   2h 20m    non-stop                      No info

# %% [markdown]
# Appneding or Merging two of the dataset

# %%
final_df = train_df.append(test_df)
final_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
final_df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %% [markdown]
# ## Feature Engineering Process

# %% [raw]
# Since we have the datetime function as an object type
# we need to convert it into datetime

# %%
#splitting out all the date month and year .... 

final_df['Date'] = final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month'] = final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year'] = final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info   Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info  3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info  7662.0    1
#
#   Month  Year
# 0    03  2019
# 1    05  2019

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  object
#  12  Month            13354 non-null  object
#  13  Year             13354 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 1.5+ MB

# %% [raw]
# Here we can see that .... Date,Month and Year are in object.
# We need to convert it into integer

# %%
final_df['Date']= final_df['Date'].astype(int)
final_df['Month']= final_df['Month'].astype(int)
final_df['Year']= final_df['Year'].astype(int)

#final_df[["Date", "Month", "Year"]] = final_df[["Date", "Month", "Year"]].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %%
final_df.drop(['Date_of_Journey'],axis=1,inplace= True)

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info   Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info  3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info  7662.0     1      5
#
#    Year
# 0  2019
# 1  2019

# %%
final_df['Arrival_Time'] = final_df['Arrival_Time'].str.split(' ').str[0]
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#   Arrival_Time Duration Total_Stops Additional_Info   Price  Date  Month  Year
# 0        01:10   2h 50m    non-stop         No info  3897.0    24      3  2019
# 1        13:15   7h 25m     2 stops         No info  7662.0     1      5  2019

# %%
final_df['Arrival_Hour'] = final_df['Arrival_Time'].str.split(':').str[0]
final_df['Arrival_Min'] = final_df['Arrival_Time'].str.split(':').str[1]
final_df.head(3)
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
#
#    Year Arrival_Hour Arrival_Min
# 0  2019           01          10
# 1  2019           13          15
# 2  2019           04          25

# %%
final_df.drop(['Arrival_Time'],axis=1,inplace=True)
final_df.head(3)
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
#
#   Total_Stops Additional_Info    Price  Date  Month  Year Arrival_Hour  \
# 0    non-stop         No info   3897.0    24      3  2019           01
# 1     2 stops         No info   7662.0     1      5  2019           13
# 2     2 stops         No info  13882.0     9      6  2019           04
#
#   Arrival_Min
# 0          10
# 1          15
# 2          25

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Arrival_Hour     13354 non-null  object
#  13  Arrival_Min      13354 non-null  object
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %%
final_df['Arrival_Hour']= final_df['Arrival_Hour'].astype(int)
final_df['Arrival_Min']= final_df['Arrival_Min'].astype(int)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Arrival_Hour     13354 non-null  int32
#  13  Arrival_Min      13354 non-null  int32
# dtypes: float64(1), int32(5), object(8)
# memory usage: 1.3+ MB

# %% [raw]
# Dealing with Dep_Time: Spliting out the values of hour and minute

# %%
final_df['Dep_Hour'] = final_df['Dep_Time'].str.split(':').str[0]
final_df['Dep_Min'] = final_df['Dep_Time'].str.split(':').str[1]
final_df.drop(['Dep_Time'],axis=1,inplace=True)
final_df.head(3)
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897.0    24      3  2019             1
# 1     2 stops         No info   7662.0     1      5  2019            13
# 2     2 stops         No info  13882.0     9      6  2019             4
#
#    Arrival_Min Dep_Hour Dep_Min
# 0           10       22      20
# 1           15       05      50
# 2           25       09      25

# %%
final_df['Dep_Hour']= final_df['Dep_Hour'].astype(int)
final_df['Dep_Min']= final_df['Dep_Min'].astype(int)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_Hour     13354 non-null  int32
#  12  Arrival_Min      13354 non-null  int32
#  13  Dep_Hour         13354 non-null  int32
#  14  Dep_Min          13354 non-null  int32
# dtypes: float64(1), int32(7), object(7)
# memory usage: 1.3+ MB

# %% [raw]
# Dealing with Total_Stops

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %% [raw]
# Since we have nan value in it ... we need to deal with this one

# %%
final_df['Total_Stops'].isnull().sum()
# Out:
# 1

# %%
#final_df['Total_Stops'].mode()
final_df['Total_Stops'].value_counts()
# Out:
# 1 stop      7056
# non-stop    4340
# 2 stops     1899
# 3 stops       56
# 4 stops        2
# Name: Total_Stops, dtype: int64

# %%
# mapping the values for Total_Stops. For the nan value we will will take mode
# Then we will drop the Route column 

final_df['Total_Stops'] = final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
#Dropping the Route column

final_df.drop(['Route'],axis=1,inplace=True)
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int32
#  8   Month            13354 non-null  int32
#  9   Year             13354 non-null  int32
#  10  Arrival_Hour     13354 non-null  int32
#  11  Arrival_Min      13354 non-null  int32
#  12  Dep_Hour         13354 non-null  int32
#  13  Dep_Min          13354 non-null  int32
# dtypes: float64(2), int32(7), object(5)
# memory usage: 1.2+ MB

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50

# %% [raw]
# Converting Duration into hours and minutes without taking h and m

# %%
final_df['Duration_Hour']=final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#   Duration_Hour
# 0             2
# 1             7
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int32
#  8   Month            13354 non-null  int32
#  9   Year             13354 non-null  int32
#  10  Arrival_Hour     13354 non-null  int32
#  11  Arrival_Min      13354 non-null  int32
#  12  Dep_Hour         13354 non-null  int32
#  13  Dep_Min          13354 non-null  int32
#  14  Duration_Hour    13354 non-null  object
# dtypes: float64(2), int32(7), object(6)
# memory usage: 1.3+ MB

# %%
final_df[final_df.Duration_Hour == '5m']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          2.0         No info
# 2660  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#         Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  \
# 6474  17327.0     6      3  2019            16           55        16
# 2660      NaN    12      3  2019            16           55        16
#
#       Dep_Min Duration_Hour
# 6474       50            5m
# 2660       50            5m

# %%
#dropping two of the rows.... from our dataset 

final_df.drop([6474,2660],axis=0,inplace=True)

# %%
final_df['Duration_Hour']= final_df['Duration_Hour'].astype(int)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13351 non-null  object
#  1   Source           13351 non-null  object
#  2   Destination      13351 non-null  object
#  3   Duration         13351 non-null  object
#  4   Total_Stops      13350 non-null  float64
#  5   Additional_Info  13351 non-null  object
#  6   Price            10681 non-null  float64
#  7   Date             13351 non-null  int32
#  8   Month            13351 non-null  int32
#  9   Year             13351 non-null  int32
#  10  Arrival_Hour     13351 non-null  int32
#  11  Arrival_Min      13351 non-null  int32
#  12  Dep_Hour         13351 non-null  int32
#  13  Dep_Min          13351 non-null  int32
#  14  Duration_Hour    13351 non-null  int32
# dtypes: float64(2), int32(8), object(5)
# memory usage: 1.2+ MB

# %%
final_df.head(3)
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
#
#      Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
#
#    Duration_Hour
# 0              2
# 1              7
# 2             19

# %% [raw]
# Dealing with Duration : Spliting out the minutes as we did for the hours

# %%
final_df['Duration_Min']=final_df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
final_df['Duration_Min'].isnull().sum()
# Out:
# 1283

# %%
final_df.head(3)
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
#
#      Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
#
#    Duration_Hour Duration_Min
# 0              2           50
# 1              7           25
# 2             19          NaN

# %% [raw]
# Since we have some values which doesn't have any minutes with it.... for those values we get NaN. now we have to fill that with 0

# %%
final_df['Duration_Min'] = final_df['Duration_Min'].fillna(0)
final_df.head(3)
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
#
#      Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
#
#    Duration_Hour Duration_Min
# 0              2           50
# 1              7           25
# 2             19            0

# %% [markdown]
# Dropping the Duration Column and change the type for the new column Duration_Min

# %%
final_df.drop(['Duration'],axis=1,inplace=True)
final_df['Duration_Min']= final_df['Duration_Min'].astype(int)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13351 non-null  object
#  1   Source           13351 non-null  object
#  2   Destination      13351 non-null  object
#  3   Total_Stops      13350 non-null  float64
#  4   Additional_Info  13351 non-null  object
#  5   Price            10681 non-null  float64
#  6   Date             13351 non-null  int32
#  7   Month            13351 non-null  int32
#  8   Year             13351 non-null  int32
#  9   Arrival_Hour     13351 non-null  int32
#  10  Arrival_Min      13351 non-null  int32
#  11  Dep_Hour         13351 non-null  int32
#  12  Dep_Min          13351 non-null  int32
#  13  Duration_Hour    13351 non-null  int32
#  14  Duration_Min     13351 non-null  int32
# dtypes: float64(2), int32(9), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Encoding the other Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
final_df.head(3)
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info    Price  \
# 0       IndiGo  Banglore   New Delhi          0.0         No info   3897.0
# 1    Air India   Kolkata    Banglore          2.0         No info   7662.0
# 2  Jet Airways     Delhi      Cochin          2.0         No info  13882.0
#
#    Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0    24      3  2019             1           10        22       20
# 1     1      5  2019            13           15         5       50
# 2     9      6  2019             4           25         9       25
#
#    Duration_Hour  Duration_Min
# 0              2            50
# 1              7            25
# 2             19             0

# %%
final_df['Airline'] = labelencoder.fit_transform(final_df['Airline'])
final_df['Source'] = labelencoder.fit_transform(final_df['Source'])
final_df['Destination'] = labelencoder.fit_transform(final_df['Destination'])
final_df['Additional_Info'] = labelencoder.fit_transform(final_df['Additional_Info'])

# %%
final_df.head(3)
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5          0.0                8   3897.0    24
# 1        1       3            0          2.0                8   7662.0     1
# 2        4       2            1          2.0                8  13882.0     9
#
#    Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  Duration_Hour  \
# 0      3  2019             1           10        22       20              2
# 1      5  2019            13           15         5       50              7
# 2      6  2019             4           25         9       25             19
#
#    Duration_Min
# 0            50
# 1            25
# 2             0

# %% [markdown]
# ## Get dummies for the Categorical after encoding

# %%
pd.get_dummies(final_df,columns = ['Airline','Source','Destination','Additional_Info'],drop_first= True)
# Out:
#       Total_Stops    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  \
# 0             0.0   3897.0    24      3  2019             1           10
# 1             2.0   7662.0     1      5  2019            13           15
# 2             2.0  13882.0     9      6  2019             4           25
# 3             1.0   6218.0    12      5  2019            23           30
# 4             1.0  13302.0     1      3  2019            21           35
# ...           ...      ...   ...    ...   ...           ...          ...
# 2666          1.0      NaN     6      6  2019            20           25
# 2667          0.0      NaN    27      3  2019            16           55
# 2668          1.0      NaN     6      3  2019             4           25
# 2669          1.0      NaN     6      3  2019            19           15
# 2670          1.0      NaN    15      6  2019            19           15
#
#       Dep_Hour  Dep_Min  Duration_Hour  ...  Destination_5  Additional_Info_1  \
# ...
